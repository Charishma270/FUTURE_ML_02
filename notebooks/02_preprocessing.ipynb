# %% [markdown]
# # 02 - Text Preprocessing
#
# Goal: create a reusable NLTK preprocessing pipeline and save a processed dataset with `cleaned_ticket`.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(ROOT / 'src'))

from preprocessing import clean_text, add_cleaned_ticket_column
from utils import load_raw_data, prepare_ticket_dataframe, PROCESSED_DATA_FILE

# %%
df = prepare_ticket_dataframe(load_raw_data())
sample_text = df.loc[0, 'ticket_text']
print('Raw text:')
print(sample_text)
print('\nCleaned text:')
print(clean_text(sample_text))

# %%
processed_df = add_cleaned_ticket_column(df)
processed_df[['ticket_text', 'cleaned_ticket', 'category', 'priority']].head()

# %%
PROCESSED_DATA_FILE.parent.mkdir(parents=True, exist_ok=True)
processed_df.to_csv(PROCESSED_DATA_FILE, index=False)
PROCESSED_DATA_FILE

# %% [markdown]
# ## Why these steps?
#
# - Lowercasing standardizes vocabulary.
# - Punctuation and special character removal reduces noise.
# - Stopword removal removes common words with little routing value.
# - Lemmatization reduces related word forms to a shared base form.
